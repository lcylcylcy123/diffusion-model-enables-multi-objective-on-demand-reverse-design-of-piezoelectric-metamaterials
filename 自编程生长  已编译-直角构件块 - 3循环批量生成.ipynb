# %%
from turtle import *
import random
from numpy import *
import math
t10=1
t20=1
t30=1
t40=1
v10=1
v20=1
v30=1
v40=1
l10=1
l20=1
l30=1
t1=t10/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
t2=t20/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
t3=t30/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
t4=t40/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
v1=v10/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
v2=v20/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
v3=v30/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
v4=v40/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
l1=l10/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
l2=l20/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
l3=l30/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
t111=0
t222=0
t333=0
t444=0
v111=0
v222=0
v333=0
v444=0
l111=0
l222=0
l333=0

# %%
def t11(x,y):
    global t111
    penup()
    goto(40+40*(x-10),20+40*(y-10))
    pendown()
    goto(0+40*(x-10),20+40*(y-10))
    goto(20+40*(x-10),20+40*(y-10))
    goto(20+40*(x-10),0+40*(y-10))
    penup()
    dic2[str(x)+','+str(y)]=str(0)+str(234)+str(5)
    t111=t111+1

# %%
def t22(x,y):
    global t222
    penup()
    goto(20+40*(x-10),0+40*(y-10))
    pendown()
    goto(20+40*(x-10),40+40*(y-10))
    goto(20+40*(x-10),20+40*(y-10))
    goto(0+40*(x-10),20+40*(y-10))
    penup()
    dic2[str(x)+','+str(y)]=str(0)+str(123)+str(8)
    t222=t222+1

# %%
def t33(x,y):
    global t333
    penup()
    goto(0+40*(x-10),20+40*(y-10))
    pendown()
    goto(40+40*(x-10),20+40*(y-10))
    goto(20+40*(x-10),20+40*(y-10))
    goto(20+40*(x-10),40+40*(y-10))
    penup()
    dic2[str(x)+','+str(y)]=str(0)+str(124)+str(7)
    t333=t333+1

# %%
def t44(x,y):
    global t444
    penup()
    goto(20+40*(x-10),40+40*(y-10))
    pendown()
    goto(20+40*(x-10),0+40*(y-10))
    goto(20+40*(x-10),20+40*(y-10))
    goto(40+40*(x-10),20+40*(y-10))
    penup()
    dic2[str(x)+','+str(y)]=str(0)+str(134)+str(6)
    t444=t444+1

# %%
def v11(x,y):
    global v111
    penup()
    goto(20+40*(x-10),40+40*(y-10))
    pendown()
    goto(20+40*(x-10),20+40*(y-10))
    goto(40+40*(x-10),20+40*(y-10))
    penup()
    dic2[str(x)+','+str(y)]=str(0)+str(14)+str(67)
    v111=v111+1

# %%
def v22(x,y):
    global v222
    penup()
    goto(20+40*(x-10),40+40*(y-10))
    pendown()
    goto(20+40*(x-10),20+40*(y-10))
    goto(0+40*(x-10),20+40*(y-10))
    penup()
    dic2[str(x)+','+str(y)]=str(0)+str(12)+str(78)
    v222=v222+1

# %%
def v33(x,y):
    global v333
    penup()
    goto(0+40*(x-10),20+40*(y-10))
    pendown()
    goto(20+40*(x-10),20+40*(y-10))
    goto(20+40*(x-10),0+40*(y-10))
    penup()
    dic2[str(x)+','+str(y)]=str(0)+str(23)+str(58)
    v333=v333+1

# %%
def v44(x,y):
    global v444
    penup()
    goto(20+40*(x-10),0+40*(y-10))
    pendown()
    goto(20+40*(x-10),20+40*(y-10))
    goto(40+40*(x-10),20+40*(y-10))
    penup()
    dic2[str(x)+','+str(y)]=str(0)+str(34)+str(56)
    v444=v444+1

# %%
def l11(x,y):
    global l111
    penup()
    goto(0+40*(x-10),20+40*(y-10))
    pendown()
    goto(40+40*(x-10),20+40*(y-10))
    penup()
    dic2[str(x)+','+str(y)]=str(0)+str(24)+str(57)
    l111=l111+1

# %%
def l22(x,y):
    global l222
    penup()
    goto(20+40*(x-10),0+40*(y-10))
    pendown()
    goto(20+40*(x-10),40+40*(y-10))
    penup()
    dic2[str(x)+','+str(y)]=str(0)+str(13)+str(68)
    l222=l222+1

# %%
def l33(x,y):
    global l333
    penup()
    goto(0+40*(x-10),20+40*(y-10))
    pendown()
    goto(40+40*(x-10),20+40*(y-10))
    penup()
    goto(20+40*(x-10),0+40*(y-10))
    pendown()
    goto(20+40*(x-10),40+40*(y-10))
    dic2[str(x)+','+str(y)]=str(0)+str(1234)
    l333=l333+1

# %%
screensize(canvwidth=800,canvheight=1000,bg='white')
pensize(4)
hideturtle()
#speed(0)
tracer(False)
pencolor("black")
lcy0=[]
lcy1=[]
lcy2=[]
lcy3=[]
lcy4=[]
lcy5=[]
lcy6=[]
lcy7=[]
lcy8=[]
lcy9=[]
lcy10=[]
lcy11=[]
import numpy as np
def generate_lhs_samples(num_samples, num_variables):
    # 生成LHS样本
    samples = np.zeros((num_samples, num_variables))

    # 生成均匀分布的子区间
    intervals = np.linspace(0, 1, num_samples + 1)

    # 对每个变量进行随机抽样
    for i in range(num_variables):
        # 在每个子区间内生成一个随机数作为样本值
        for j in range(num_samples):
            low = intervals[j]
            high = intervals[j + 1]
            samples[j, i] = np.random.uniform(low, high)

        # 对每列样本进行随机重排
        np.random.shuffle(samples[:, i])

    return samples

# 示例用法
num_samples = 17000
num_variables = 11

samples = generate_lhs_samples(num_samples, num_variables)
for lc in range(0,17000):
    pensize(4)
    #speed(0)
    tracer(False)
    t10=samples[lc-10800][0]
    t20=samples[lc-10800][1]
    t30=samples[lc-10800][2]
    t40=samples[lc-10800][3]
    v10=samples[lc-10800][4]
    v20=samples[lc-10800][5]
    v30=samples[lc-10800][6]
    v40=samples[lc-10800][7]
    l10=samples[lc-10800][8]
    l20=samples[lc-10800][9]
    l30=samples[lc-10800][10]
    t1=t10/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
    t2=t20/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
    t3=t30/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
    t4=t40/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
    v1=v10/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
    v2=v20/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
    v3=v30/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
    v4=v40/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
    l1=l10/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
    l2=l20/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
    l3=l30/(t10+t20+t30+t40+v10+v20+v30+v40+l10+l20+l30)
    t111=0
    t222=0
    t333=0
    t444=0
    v111=0
    v222=0
    v333=0
    v444=0
    l111=0
    l222=0
    l333=0
    dic1={}# 记录是否填充了模块  和是否具有节点
    dic2={}# 记录模块所具有的节点
    dic3={}# 记录每一个节点的节点熵
    for i in range(1,21):
        for j in range(1,21):
            dic1[str(i)+','+str(j)]=str(1)
    for i in range(1,21):
        for j in range(1,21):
            dic2[str(i)+','+str(j)]=str(0)
    for i in range(1,21):
        for j in range(1,21):
            dic3[str(i)+','+str(j)]=100000
    p=random.random()
    if p<t1:
        t11(10,10)
        dic1['10,10']=str(2)
        dic2['10,10']=str(0)+str(234)+str(5)
    if t1<=p<t1+t2:
        t22(10,10)
        dic1['10,10']=str(2)
        dic2['10,10']=str(0)+str(123)+str(8)
    if t1+t2<=p<t1+t2+t3:
        t33(10,10)
        dic1['10,10']=str(2)
        dic2['10,10']=str(0)+str(124)+str(7)
    if t1+t2+t3<=p<t1+t2+t3+t4:
        t44(10,10)
        dic1['10,10']=str(2)
        dic2['10,10']=str(0)+str(134)+str(6)
    if t1+t2+t3+t4<=p<t1+t2+t3+t4+v1:
        v11(10,10)
        dic1['10,10']=str(2)
        dic2['10,10']=str(0)+str(14)+str(67)
    if t1+t2+t3+t4+v1<=p<t1+t2+t3+t4+v1+v2:
        v22(10,10)
        dic1['10,10']=str(2)
        dic2['10,10']=str(0)+str(12)+str(78)
    if t1+t2+t3+t4+v1+v2<=p<t1+t2+t3+t4+v1+v2+v3:
        v33(10,10)
        dic1['10,10']=str(2)
        dic2['10,10']=str(0)+str(23)+str(58)
    if t1+t2+t3+t4+v1+v2+v3<=p<t1+t2+t3+t4+v1+v2+v3+v4:
        v44(10,10)
        dic1['10,10']=str(2)
        dic2['10,10']=str(0)+str(34)+str(56)
    if t1+t2+t3+t4+v1+v2+v3+v4<=p<t1+t2+t3+t4+v1+v2+v3+v4+l1:
        l11(10,10)
        dic1['10,10']=str(2)
        dic2['10,10']=str(0)+str(24)+str(57)
    if t1+t2+t3+t4+v1+v2+v3+v4+l1<=p<t1+t2+t3+t4+v1+v2+v3+v4+l1+l2:
        l22(10,10)
        dic1['10,10']=str(2)
        dic2['10,10']=str(0)+str(13)+str(68)
    if t1+t2+t3+t4+v1+v2+v3+v4+l1+l2<=p<1:
        l33(10,10)
        dic1['10,10']=str(2)
        dic2['10,10']=str(0)+str(1234)
    n=1
    while n<400:
        for i in range(1,21):
            for j in range(1,21):
                if dic1[str(i)+','+str(j)]==str(2):
                    a=dic2[str(i)+','+str(j)]
                    if '3'in a and 1<=j-1<=20 and (dic1[str(i)+','+str(j-1)]==str(1) or dic1[str(i)+','+str(j-1)]==str(3)) and '1' not in dic2[str(i)+','+str(j-1)]:
                        dic2[str(i)+','+str(j-1)]=dic2[str(i)+','+str(j-1)]+str(1)
                        dic1[str(i)+','+str(j-1)]=str(3)
                    if '4'in a and 1<=i+1<=20 and (dic1[str(i+1)+','+str(j)]==str(1) or dic1[str(i+1)+','+str(j)]==str(3)) and '2' not in dic2[str(i+1)+','+str(j)]:
                        dic2[str(i+1)+','+str(j)]=dic2[str(i+1)+','+str(j)]+str(2)
                        dic1[str(i+1)+','+str(j)]=str(3)
                    if '1'in a and 1<=j+1<=20 and (dic1[str(i)+','+str(j+1)]==str(1) or dic1[str(i)+','+str(j+1)]==str(3)) and '3' not in dic2[str(i)+','+str(j+1)]: 
                        dic2[str(i)+','+str(j+1)]=dic2[str(i)+','+str(j+1)]+str(3)
                        dic1[str(i)+','+str(j+1)]=str(3)
                    if '2'in a and 1<=i-1<=20 and (dic1[str(i-1)+','+str(j)]==str(1) or dic1[str(i-1)+','+str(j)]==str(3)) and '4' not in dic2[str(i-1)+','+str(j)]:
                        dic2[str(i-1)+','+str(j)]=dic2[str(i-1)+','+str(j)]+str(4)
                        dic1[str(i-1)+','+str(j)]=str(3)
                    if '7'in a and 1<=j-1<=20 and (dic1[str(i)+','+str(j-1)]==str(1) or dic1[str(i)+','+str(j-1)]==str(3)) and '5' not in dic2[str(i)+','+str(j-1)]:
                        dic2[str(i)+','+str(j-1)]=dic2[str(i)+','+str(j-1)]+str(5)
                    if '8'in a and 1<=i+1<=20 and (dic1[str(i+1)+','+str(j)]==str(1) or dic1[str(i+1)+','+str(j)]==str(3)) and '6' not in dic2[str(i+1)+','+str(j)]:
                        dic2[str(i+1)+','+str(j)]=dic2[str(i+1)+','+str(j)]+str(6)
                    if '5'in a and 1<=j+1<=20 and (dic1[str(i)+','+str(j+1)]==str(1) or dic1[str(i)+','+str(j+1)]==str(3)) and '7' not in dic2[str(i)+','+str(j+1)]:
                        dic2[str(i)+','+str(j+1)]=dic2[str(i)+','+str(j+1)]+str(7)
                    if '6'in a and 1<=i-1<=20 and (dic1[str(i-1)+','+str(j)]==str(1) or dic1[str(i-1)+','+str(j)]==str(3)) and '8' not in dic2[str(i-1)+','+str(j)]:
                        dic2[str(i-1)+','+str(j)]=dic2[str(i-1)+','+str(j)]+str(8)
        for i in range(1,21):
            for j in range(1,21):
                if dic1[str(i)+','+str(j)]==str(3):
                    b=dic2[str(i)+','+str(j)]
                    l=list(b)
                    l.sort()
                    b="".join(l)
                    if b=='01234':
                        s=0
                        dic3[str(i)+','+str(j)]=s          
                    if b=='0123' :
                        p1=l3/(l3+t2)
                        p2=t2/(l3+t2)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='01238':
                        s=0
                        dic3[str(i)+','+str(j)]=s    
                    if b=='0124':
                        p1=l3/(l3+t3)
                        p2=t3/(l3+t3)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='01247':
                        s=0
                        dic3[str(i)+','+str(j)]=s    
                    if b=='0134':
                        p1=l3/(l3+t4)
                        p2=t4/(l3+t4)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='01346':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='0234':
                        p1=l3/(l3+t1)
                        p2=t1/(l3+t1)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='02345':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='012':
                        p1=l3/(l3+t2+t3+v2)
                        p2=t2/(l3+t2+t3+v2)
                        p3=t3/(l3+t2+t3+v2)
                        p4=v2/(l3+t2+t3+v2)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3)+p4*log(p4))
                        dic3[str(i)+','+str(j)]=s
                    if b=='0127':
                        p1=t3/(t3+v2)
                        p2=v2/(t3+v2)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='0128':
                        p1=t2/(t2+v2)
                        p2=v2/(t2+v2)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='01278':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='013':
                        p1=l3/(l3+t2+t4+l2)
                        p2=t2/(l3+t2+t4+l2)
                        p3=t4/(l3+t2+t4+l2)
                        p4=l2/(l3+t2+t4+l2)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3)+p4*log(p4))
                        dic3[str(i)+','+str(j)]=s
                    if b=='0136':
                        p1=t4/(t4+l2)
                        p2=l2/(t4+l2)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='0138':
                        p1=t2/(t2+l2)
                        p2=l2/(t2+l2)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='01368':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='014':
                        p1=l3/(l3+t3+t4+v1)
                        p2=t3/(l3+t3+t4+v1)
                        p3=t4/(l3+t3+t4+v1)
                        p4=v1/(l3+t3+t4+v1)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3)+p4*log(p4))
                        dic3[str(i)+','+str(j)]=s
                    if b=='0146':
                        p1=t4/(t4+v1)
                        p2=v1/(t4+v1)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if  b=='0147':
                        p1=t3/(t3+v1)
                        p2=v1/(t3+v1)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if  b=='01467':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if  b=='023':
                        p1=l3/(l3+t1+t2+v3)
                        p2=t1/(l3+t1+t2+v3)
                        p3=t2/(l3+t1+t2+v3)
                        p4=v3/(l3+t1+t2+v3)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3)+p4*log(p4))
                        dic3[str(i)+','+str(j)]=s
                    if b=='0235':
                        p1=t1/(t1+v3)
                        p2=v3/(t1+v3)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='0238':
                        p1=t2/(t2+v3)
                        p2=v3/(t2+v3)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='02358':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='024':
                        p1=l3/(l3+t1+t3+l1)
                        p2=t1/(l3+t1+t3+l1)
                        p3=t3/(l3+t1+t3+l1)
                        p4=l1/(l3+t1+t3+l1)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3)+p4*log(p4))
                        dic3[str(i)+','+str(j)]=s
                    if b=='0245':
                        p1=l1/(l1+t1)
                        p2=t1/(l1+t1)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='0247':
                        p1=l1/(l1+t3)
                        p2=t3/(l1+t3)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='02457':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='034':
                        p1=l3/(l3+t1+t4+v4)
                        p2=t1/(l3+t1+t4+v4)
                        p3=t4/(l3+t1+t4+v4)
                        p4=v4/(l3+t1+t4+v4)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3)+p4*log(p4))
                        dic3[str(i)+','+str(j)]=s
                    if b=='0345':
                        p1=v4/(v4+t1)
                        p2=t1/(v4+t1)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='0346':
                        p1=v4/(v4+t4)
                        p2=t4/(v4+t4)
                        s=-(p1*log(p1)+p2*log(p2))
                        dic3[str(i)+','+str(j)]=s
                    if b=='03456':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='01':
                        p1=l3/(l3+t2+t3+t4+v1+v2+l2)
                        p2=t2/(l3+t2+t3+t4+v1+v2+l2)
                        p3=t3/(l3+t2+t3+t4+v1+v2+l2)
                        p4=t4/(l3+t2+t3+t4+v1+v2+l2)
                        p5=v1/(l3+t2+t3+t4+v1+v2+l2)
                        p6=v2/(l3+t2+t3+t4+v1+v2+l2)
                        p7=l2/(l3+t2+t3+t4+v1+v2+l2)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3)+p4*log(p4)+p5*log(p5)+p6*log(p6)+p7*log(p7))
                        dic3[str(i)+','+str(j)]=s
                    if b=='016':
                        p1=t4/(t4+v1+l2)
                        p2=v1/(t4+v1+l2)
                        p3=l2/(t4+v1+l2)    
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))        
                        dic3[str(i)+','+str(j)]=s
                    if b=='017':
                        p1=t3/(t3+v1+v2)
                        p2=v1/(t3+v1+v2)
                        p3=v2/(t3+v1+v2)   
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))    
                        dic3[str(i)+','+str(j)]=s
                    if b=='018':
                        p1=t2/(t2+l2+v2)
                        p2=l2/(t2+l2+v2)
                        p3=v2/(t2+l2+v2)   
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))        
                        dic3[str(i)+','+str(j)]=s
                    if b=='0167':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='0168':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='0178':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='01678':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='02':
                        p1=l3/(l3+t1+t2+t3+v2+v3+l1)
                        p2=t1/(l3+t1+t2+t3+v2+v3+l1)
                        p3=t2/(l3+t1+t2+t3+v2+v3+l1)
                        p4=t3/(l3+t1+t2+t3+v2+v3+l1)
                        p5=v2/(l3+t1+t2+t3+v2+v3+l1)
                        p6=v3/(l3+t1+t2+t3+v2+v3+l1)
                        p7=l1/(l3+t1+t2+t3+v2+v3+l1)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3)+p4*log(p4)+p5*log(p5)+p6*log(p6)+p7*log(p7))
                        dic3[str(i)+','+str(j)]=s
                    if b=='025':
                        p1=t1/(t1+v3+l1)
                        p2=v3/(t1+v3+l1)
                        p3=l1/(t1+v3+l1)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))       
                        dic3[str(i)+','+str(j)]=s
                    if b=='027':
                        p1=t3/(t3+v2+l1)
                        p2=v2/(t3+v2+l1)
                        p3=l1/(t3+v2+l1)    
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))       
                        dic3[str(i)+','+str(j)]=s    
                    if b=='028':
                        p1=t2/(t2+v2+v3)
                        p2=v2/(t2+v2+v3)
                        p3=v3/(t2+v2+v3)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))      
                        dic3[str(i)+','+str(j)]=s 
                    if b=='0257':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='0258':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='0278':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='02578':    
                        s=0
                        dic3[str(i)+','+str(j)]=s

                    if b=='03':
                        p1=l3/(l3+t1+t2+t4+v3+v4+l2)
                        p2=t1/(l3+t1+t2+t4+v3+v4+l2)
                        p3=t2/(l3+t1+t2+t4+v3+v4+l2)
                        p4=t4/(l3+t1+t2+t4+v3+v4+l2)
                        p5=v3/(l3+t1+t2+t4+v3+v4+l2)
                        p6=v4/(l3+t1+t2+t4+v3+v4+l2)
                        p7=l2/(l3+t1+t2+t4+v3+v4+l2)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3)+p4*log(p4)+p5*log(p5)+p6*log(p6)+p7*log(p7))
                        dic3[str(i)+','+str(j)]=s
                    if b=='035':
                        p1=t1/(t1+v3+v4)
                        p2=v3/(t1+v3+v4)
                        p3=v4/(t1+v3+v4)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))
                        dic3[str(i)+','+str(j)]=s 
                    if b=='036':
                        p1=t4/(t4+v4+l2)
                        p2=v4/(t4+v4+l2)
                        p3=l2/(t4+v4+l2)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))
                        dic3[str(i)+','+str(j)]=s 
                    if b=='038':
                        p1=t2/(t2+v3+l2)
                        p2=v3/(t2+v3+l2)
                        p3=l2/(t2+v3+l2)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))
                        dic3[str(i)+','+str(j)]=s 
                    if b=='0356':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='0358':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='0368':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='03568':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='04':
                        p1=l3/(l3+t1+t3+t4+v1+v4+l1)
                        p2=t1/(l3+t1+t3+t4+v1+v4+l1)
                        p3=t3/(l3+t1+t3+t4+v1+v4+l1)
                        p4=t4/(l3+t1+t3+t4+v1+v4+l1)
                        p5=v1/(l3+t1+t3+t4+v1+v4+l1)
                        p6=v4/(l3+t1+t3+t4+v1+v4+l1)
                        p7=l1/(l3+t1+t3+t4+v1+v4+l1)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))
                        dic3[str(i)+','+str(j)]=s 
                    if b=='045':
                        p1=t1/(t1+v4+l1)
                        p2=v4/(t1+v4+l1)
                        p3=l1/(t1+v4+l1)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))
                        dic3[str(i)+','+str(j)]=s 
                    if b=='046':
                        p1=t4/(t4+v1+v4)
                        p2=v1/(t4+v1+v4)
                        p3=v4/(t4+v1+v4)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))
                        dic3[str(i)+','+str(j)]=s 
                    if b=='047':
                        p1=t3/(t3+v1+l1)
                        p2=v1/(t3+v1+l1)
                        p3=l1/(t3+v1+l1)
                        s=-(p1*log(p1)+p2*log(p2)+p3*log(p3))
                        dic3[str(i)+','+str(j)]=s 
                    if b=='0456':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='0457':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='0467':
                        s=0
                        dic3[str(i)+','+str(j)]=s
                    if b=='04567':
                        s=0
                        dic3[str(i)+','+str(j)]=s
        ls=sorted(dic3.items(),key = lambda x:x[1])
        value=ls[0][1]
        k2 = [k for k, v in dic3.items() if v == value]
        m=len(k2)
        if m>1:
            kp=random.randint(0, m-1)
            mins=k2[kp]
        if m==1:
            mins=k2[0]
        dic1[mins]=str(2)
        dic3[mins]=10000001
        b=dic2[mins]
        l=list(b)
        l.sort()
        b="".join(l)
        mins=mins.split(',')
        x=int(mins[0])
        y=int(mins[1])
        n=n+1
        if b=='01234':
            l33(x,y)
        if  b=='0123':
            p1=l3/(l3+t2)
            p2=t2/(l3+t2)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<=1:
                t22(x,y)
        if b=='01238':
            t22(x,y)
        if b=='0124':
            p1=l3/(l3+t3)
            p2=t3/(l3+t3)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<=1:
                t33(x,y)
        if b=='01247':
            t33(x,y) 
        if  b=='0134':
            p1=l3/(l3+t4)
            p2=t4/(l3+t4)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<=1:
                t44(x,y)
        if b=='01346':
            t44(x,y)
        if b=='0234':
            p1=l3/(l3+t1)
            p2=t1/(l3+t1)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<=1:
                t11(x,y)
        if b=='02345':
            t11(x,y)
        if b=='012':
            p1=l3/(l3+t2+t3+v2)
            p2=t2/(l3+t2+t3+v2)
            p3=t3/(l3+t2+t3+v2)
            p4=v2/(l3+t2+t3+v2)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<p1+p2:
                t22(x,y)
            if p1+p2<=p<p1+p2+p3:
                t33(x,y)
            if p1+p2+p3<=p<1:
                v22(x,y)
        if b=='0127':
            p1=t3/(t3+v2)
            p2=v2/(t3+v2)
            p=random.random()
            if 0<=p<p1:
                t33(x,y)
            if p1<=p<=1:
                v22(x,y)
        if b=='0128':
            p1=t2/(t2+v2)
            p2=v2/(t2+v2)
            p=random.random()
            if 0<=p<p1:
                t22(x,y)
            if p1<=p<=1:
                v22(x,y)
        if b=='01278':
            v22(x,y)
        if b=='013':
            p1=l3/(l3+t2+t4+l2)
            p2=t2/(l3+t2+t4+l2)
            p3=t4/(l3+t2+t4+l2)
            p4=l2/(l3+t2+t4+l2)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<p1+p2:
                t22(x,y)
            if p1+p2<=p<p1+p2+p3:
                t44(x,y)
            if p1+p2+p3<=p<1:
                l22(x,y)
        if b=='0136':
            p1=t4/(t4+l2)
            p2=l2/(t4+l2)
            p=random.random()
            if 0<=p<p1:
                t44(x,y)
            if p1<=p<=1:
                l22(x,y)
        if b=='0138':
            p1=t2/(t2+l2)
            p2=l2/(t2+l2)
            p=random.random()
            if 0<=p<p1:
                t22(x,y)
            if p1<=p<=1:
                l22(x,y)
        if b=='01368':
            l22(x,y)
        if b=='014':
            p1=l3/(l3+t3+t4+v1)
            p2=t3/(l3+t3+t4+v1)
            p3=t4/(l3+t3+t4+v1)
            p4=v1/(l3+t3+t4+v1)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<p1+p2:
                t33(x,y)
            if p1+p2<=p<p1+p2+p3:
                t44(x,y)
            if p1+p2+p3<=p<1:
                v11(x,y)
        if b=='0146':
            p1=t4/(t4+v1)
            p2=v1/(t4+v1)
            p=random.random()
            if 0<=p<p1:
                t44(x,y)
            if p1<=p<=1:
                v11(x,y)
        if b=='0147':
            p1=t3/(t3+v1)
            p2=v1/(t3+v1)
            p=random.random()
            if 0<=p<p1:
                t33(x,y)
            if p1<=p<=1:
                v11(x,y)
        if b=='01467':
            v11(x,y)
        if b=='023':
            p1=l3/(l3+t1+t2+v3)
            p2=t1/(l3+t1+t2+v3)
            p3=t2/(l3+t1+t2+v3)
            p4=v3/(l3+t1+t2+v3)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<p1+p2:
                t11(x,y)
            if p1+p2<=p<p1+p2+p3:
                t22(x,y)
            if p1+p2+p3<=p<1:
                v33(x,y)
        if b=='0235':
            p1=t1/(t1+v3)
            p2=v3/(t1+v3)
            p=random.random()
            if 0<=p<p1:
                t11(x,y)
            if p1<=p<=1:
                v33(x,y)
        if b=='0238':
            p1=t2/(t2+v3)
            p2=v3/(t2+v3)
            p=random.random()
            if 0<=p<p1:
                t22(x,y)
            if p1<=p<=1:
                v33(x,y)
        if b=='02358':
            v33(x,y)
        if b=='024':
            p1=l3/(l3+t1+t3+l1)
            p2=t1/(l3+t1+t3+l1)
            p3=t3/(l3+t1+t3+l1)
            p4=l1/(l3+t1+t3+l1)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<p1+p2:
                t11(x,y)
            if p1+p2<=p<p1+p2+p3:
                t33(x,y)
            if p1+p2+p3<=1<1:
                l11(x,y)
        if b=='0245':
            p1=l1/(l1+t1)
            p2=t1/(l1+t1)
            p=random.random()
            if 0<=p<p1:
                l11(x,y)
            if p1<=p<=1:
                t11(x,y)
        if b=='0247':
            p1=l1/(l1+t3)
            p2=t3/(l1+t3)
            p=random.random()
            if 0<=p<p1:
                l11(x,y)
            if p1<=p<=1:
                t33(x,y)
        if b=='02457':
            l11(x,y)
        if b=='034':
            p1=l3/(l3+t1+t4+v4)
            p2=t1/(l3+t1+t4+v4)
            p3=t4/(l3+t1+t4+v4)
            p4=v4/(l3+t1+t4+v4)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<p1+p2:
                t11(x,y)
            if p1+p2<=p<p1+p2+p3:
                t44(x,y)
            if p1+p2+p3<=p<1:
                v44(x,y)
        if b=='0345':
            p1=v4/(v4+t1)
            p2=t1/(v4+t1)
            p=random.random()
            if 0<=p<p1:
                v44(x,y)
            if p1<=p<=1:
                t11(x,y)
        if b=='0346':
            p1=v4/(v4+t4)
            p2=t4/(v4+t4)
            p=random.random()
            if 0<=p<p1:
                v44(x,y)
            if p1<=p<=1:
                t44(x,y)
        if b=='03456':
            v44(x,y)
        if b=='01':
            p1=l3/(l3+t2+t3+t4+v1+v2+l2)
            p2=t2/(l3+t2+t3+t4+v1+v2+l2)
            p3=t3/(l3+t2+t3+t4+v1+v2+l2)
            p4=t4/(l3+t2+t3+t4+v1+v2+l2)
            p5=v1/(l3+t2+t3+t4+v1+v2+l2)
            p6=v2/(l3+t2+t3+t4+v1+v2+l2)
            p7=l2/(l3+t2+t3+t4+v1+v2+l2)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<p1+p2:
                t22(x,y)
            if p1+p2<=p<p1+p2+p3:
                t33(x,y)
            if p1+p2+p3<=p<p1+p2+p3+p4:
                t44(x,y)
            if p1+p2+p3+p4<=p<p1+p2+p3+p4+p5:
                v11(x,y)
            if p1+p2+p3+p4+p5<=p<p1+p2+p3+p4+p5+p6:
                v22(x,y)
            if p1+p2+p3+p4+p5+p6<=p<1:
                l22(x,y)
        if b=='016':
            p1=t4/(t4+v1+l2)
            p2=v1/(t4+v1+l2)
            p3=l2/(t4+v1+l2)    
            p=random.random()
            if 0<=p<p1:
                t44(x,y)
            if p1<=p<p1+p2:
                v11(x,y)
            if p1+p2<=p<1:
                l22(x,y)
        if b=='017':
            p1=t3/(t3+v1+v2)
            p2=v1/(t3+v1+v2)
            p3=v2/(t3+v1+v2)   
            p=random.random()
            if 0<=p<p1:
                t33(x,y)
            if p1<=p<p1+p2:
                v11(x,y)
            if p1+p2<=p<1:
                v22(x,y)
        if b=='018':
            p1=t2/(t2+l2+v2)
            p2=l2/(t2+l2+v2)
            p3=v2/(t2+l2+v2)   
            p=random.random()
            if 0<=p<p1:
                t22(x,y)
            if p1<=p<p1+p2:
                l22(x,y)
            if p1+p2<=p<1:
                v22(x,y)
        if b=='0167':
            v11(x,y)
        if b=='0168':
            l22(x,y)
        if b=='0178':
            v22(x,y)
        if b=='02':
            p1=l3/(l3+t1+t2+t3+v2+v3+l1)
            p2=t1/(l3+t1+t2+t3+v2+v3+l1)
            p3=t2/(l3+t1+t2+t3+v2+v3+l1)
            p4=t3/(l3+t1+t2+t3+v2+v3+l1)
            p5=v2/(l3+t1+t2+t3+v2+v3+l1)
            p6=v3/(l3+t1+t2+t3+v2+v3+l1)
            p7=l1/(l3+t1+t2+t3+v2+v3+l1)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<p1+p2:
                t11(x,y)
            if p1+p2<=p<p1+p2+p3:
                t22(x,y)
            if p1+p2+p3<=p<p1+p2+p3+p4:
                t33(x,y)
            if p1+p2+p3+p4<=p<p1+p2+p3+p4+p5:
                v22(x,y)
            if p1+p2+p3+p4+p5<=p<p1+p2+p3+p4+p5+p6:
                v33(x,y)
            if p1+p2+p3+p4+p5+p6<=p<1:
                l11(x,y)
        if b=='025':
            p1=t1/(t1+v3+l1)
            p2=v3/(t1+v3+l1)
            p3=l1/(t1+v3+l1)
            p=random.random()
            if 0<=p<p1:
                t11(x,y)
            if p1<=p<p1+p2:
                v33(x,y)
            if p1+p2<=p<1:
                l11(x,y)
        if b=='027':
            p1=t3/(t3+v2+l1)
            p2=v2/(t3+v2+l1)
            p3=l1/(t3+v2+l1)    
            p=random.random()
            if 0<=p<p1:
                t33(x,y)
            if p1<=p<p1+p2:
                v22(x,y)
            if p1+p2<=p<1:
                l11(x,y)   
        if b=='028':
            p1=t2/(t2+v2+v3)
            p2=v2/(t2+v2+v3)
            p3=v3/(t2+v2+v3)
            p=random.random()
            if 0<=p<p1:
                t22(x,y)
            if p1<=p<p1+p2:
                v22(x,y)
            if p1+p2<=p<1:
                v33(x,y)
        if b=='0257':
            l11(x,y)
        if b=='0258':
            v33(x,y)
        if b=='0278':
            v22(x,y)
        if b=='03':
            p1=l3/(l3+t1+t2+t4+v3+v4+l2)
            p2=t1/(l3+t1+t2+t4+v3+v4+l2)
            p3=t2/(l3+t1+t2+t4+v3+v4+l2)
            p4=t4/(l3+t1+t2+t4+v3+v4+l2)
            p5=v3/(l3+t1+t2+t4+v3+v4+l2)
            p6=v4/(l3+t1+t2+t4+v3+v4+l2)
            p7=l2/(l3+t1+t2+t4+v3+v4+l2)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<p1+p2:
                t11(x,y)
            if p1+p2<=p<p1+p2+p3:
                t22(x,y)
            if p1+p2+p3<=p<p1+p2+p3+p4:
                t44(x,y)
            if p1+p2+p3+p4<=p<p1+p2+p3+p4+p5:
                v33(x,y)
            if p1+p2+p3+p4+p5<=p<p1+p2+p3+p4+p5+p6:
                v44(x,y)
            if p1+p2+p3+p4+p5+p6<=p<1:
                l22(x,y)
        if b=='035':
            p1=t1/(t1+v3+v4)
            p2=v3/(t1+v3+v4)
            p3=v4/(t1+v3+v4)
            p=random.random()
            if 0<=p<p1:
                t11(x,y)
            if p1<=p<p1+p2:
                v33(x,y)
            if p1+p2<=p<1:
                v44(x,y)
        if  b=='036':
            p1=t4/(t4+v4+l2)
            p2=v4/(t4+v4+l2)
            p3=l2/(t4+v4+l2)
            p=random.random()
            if 0<=p<p1:
                t44(x,y)
            if p1<=p<p1+p2:
                v44(x,y)
            if p1+p2<=p<1:
                l22(x,y)
        if b=='038':
            p1=t2/(t2+v3+l2)
            p2=v3/(t2+v3+l2)
            p3=l2/(t2+v3+l2)
            p=random.random()
            if 0<=p<p1:
                t22(x,y)
            if p1<=p<p1+p2:
                v33(x,y)
            if p1+p2<=p<1:
                l22(x,y)
        if b=='0356':
            v44(x,y)
        if b=='0358':
            v33(x,y)
        if b=='0368':
            l22(x,y)
        if b=='04':
            p1=l3/(l3+t1+t3+t4+v1+v4+l1)
            p2=t1/(l3+t1+t3+t4+v1+v4+l1)
            p3=t3/(l3+t1+t3+t4+v1+v4+l1)
            p4=t4/(l3+t1+t3+t4+v1+v4+l1)
            p5=v1/(l3+t1+t3+t4+v1+v4+l1)
            p6=v4/(l3+t1+t3+t4+v1+v4+l1)
            p7=l1/(l3+t1+t3+t4+v1+v4+l1)
            p=random.random()
            if 0<=p<p1:
                l33(x,y)
            if p1<=p<p1+p2:
                t11(x,y)
            if p1+p2<=p<p1+p2+p3:
                t33(x,y)
            if p1+p2+p3<=p<p1+p2+p3+p4:
                t44(x,y)
            if p1+p2+p3+p4<=p<p1+p2+p3+p4+p5:
                v11(x,y)
            if p1+p2+p3+p4+p5<=p<p1+p2+p3+p4+p5+p6:
                v44(x,y)
            if p1+p2+p3+p4+p5+p6<=p<1:
                l11(x,y)
        if b=='045':
            p1=t1/(t1+v4+l1)
            p2=v4/(t1+v4+l1)
            p3=l1/(t1+v4+l1)
            p=random.random()
            if 0<=p<p1:
                t11(x,y)
            if p1<=p<p1+p2:
                v44(x,y)
            if p1+p2<=p:
                l11(x,y)
        if b=='046':
            p1=t4/(t4+v1+v4)
            p2=v1/(t4+v1+v4)
            p3=v4/(t4+v1+v4)
            p=random.random()
            if 0<=p<p1:
                t44(x,y)
            if p1<=p<p1+p2:
                v11(x,y)
            if p1+p2<=p:
                v44(x,y)
        if b=='047':
            p1=t3/(t3+v1+l1)
            p2=v1/(t3+v1+l1)
            p3=l1/(t3+v1+l1)
            p=random.random()
            if 0<=p<p1:
                t33(x,y)
            if p1<=p<p1+p2:
                v11(x,y)
            if p1+p2<=p:
                l11(x,y) 
        if b=='0456':
            v44(x,y)
            n=n+1
        if b=='0457':
            l11(x,y)
            n=n+1
        if b=='0467':
            v11(x,y)    
    penup()
    goto(40*(1-10),40+40*(20-10)+1)
    pendown()
    goto(40*(21-10),40+40*(20-10)+1)
    penup()
    goto(40*(1-10),40*(1-10)-1)
    pendown()
    goto(40*(21-10),40*(1-10)-1) #两边用板子封住
    penup()
    goto(40*(1-10),40+40*(20-10)+1)
    pendown()
    goto(40*(1-10),40*(1-10)-1)
    penup()
    goto(40*(21-10),40+40*(20-10)+1)
    pendown()
    goto(40*(21-10),40*(1-10)-1)
    penup()
    goto(40*(21-10),40+40*(20-10)+1)
    pendown()
    goto(40*(21-10),40*(1-10)-1)
    tsimg = getscreen()
    tsimg.getcanvas().postscript(file="E:/work90.eps")
    from PIL import Image
    im = Image.open("E:/work90.eps")
    path1='E:\picturedataplus\lcy'+str(lc)+'.jpg'
    im.save(path1, "JPEG")
    lcy0.append(lc)
    lcy1.append(t111)
    lcy2.append(t222)
    lcy3.append(t333)
    lcy4.append(t444)
    lcy5.append(v111)
    lcy6.append(v222)
    lcy7.append(v333)
    lcy8.append(v444)
    lcy9.append(l111)
    lcy10.append(l222)
    lcy11.append(l333)
    reset()
    #mainloop()
    #done()
import pandas as pd
data=zip(lcy0,lcy1,lcy2,lcy3,lcy4,lcy5,lcy6,lcy7,lcy8,lcy9,lcy10,lcy11)
test=pd.DataFrame(data=data)
test.to_csv('E:\picturedataplus\picturedataplus.csv',encoding='utf-8-sig')
mainloop()
done()
